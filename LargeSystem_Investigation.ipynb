# %% [markdown]
# # Investigating linear solvers options on flow problem with random fractures
# Here we focus on problem with >10.000 elemets
#
#
# [Not yet ready to commit, repeats the script as Problem_Investigation.ipynb, will be later used to create a dataset to my first ML model ]

# %% [markdown]
# Import necessery packages:

# %%
import numpy as np
import porepy as pp
import FTHM_Solver
import scipy.stats as stats
from pprint import pprint

# %% [markdown]
# And few additional ones

# %%
import time
import pandas as pd
import copy
from joblib import Parallel, delayed, parallel_backend
import itertools
import gmsh

import math
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt

# %% [markdown]
# This bit is from flow_setup.py

# %%
from porepy.examples.flow_benchmark_2d_case_4 import (
    FlowBenchmark2dCase4Model,
    solid_constants as solid_constants_2d,
)


class StochasticGeometry:
    def set_fractures(self):
        np.random.seed(self.params.get("seed", 42))

        num_fractures = self.params.get("num_fractures", 10)

        # Generate random fracture orientations. For now, we assume uniform distribution
        # of orientations in the range [0, pi]. We may change this later.
        orientation_distr = stats.uniform(loc=0, scale=np.pi)
        orientation = orientation_distr.rvs(size=num_fractures)

        # Represent fracture lengths as a log-normal distribution. The parameters set
        # here are quite random.
        length_distr = stats.lognorm(s=1, scale=0.5)
        lengths = length_distr.rvs(size=num_fractures)

        # Generate random fracture centers. For now, we assume uniform distribution
        # of positions in the range [0, 1] in both x and y directions.
        position_distr = stats.uniform(loc=0, scale=1)
        positions_x = position_distr.rvs(size=num_fractures)
        positions_y = position_distr.rvs(size=num_fractures)

        # Create the endpoints of the fractures based on the lengths and orientations.
        endpoints = []
        for i in range(num_fractures):
            cx = positions_x[i]
            cy = positions_y[i]
            length = lengths[i]
            theta = orientation[i]

            x0 = cx - 0.5 * length * np.cos(theta)
            y0 = cy - 0.5 * length * np.sin(theta)

            p0 = np.array([x0, y0]).reshape((2, 1))

            x1 = cx + 0.5 * length * np.cos(theta)
            y1 = cy + 0.5 * length * np.sin(theta)
            p1 = np.array([x1, y1]).reshape((2, 1))

            endpoints.append(np.hstack([p0, p1]))

        # Create the fractures as line segments.
        fractures = []
        for point_pairs in endpoints:
            fractures.append(pp.LineFracture(point_pairs))

        # Set the fractures in the model.
        self._fractures = fractures

    def grid_type(self):
        return "simplex"


class Source:
    def fluid_source(self, subdomains: list[pp.Grid]) -> pp.ad.Operator:
        domain = self.domain
        box = domain.bounding_box_from_polytope()

        x_mean = (box["xmax"] + box["xmin"]) / 2
        y_mean = (box["ymax"] + box["ymin"]) / 2

        src_ambient = np.zeros(
            sum(sd.num_cells for sd in subdomains if sd.dim == self.nd)
        )
        src_fracture = np.zeros(
            sum(sd.num_cells for sd in subdomains if sd.dim == self.nd - 1)
        )
        src_intersection = np.zeros(
            sum(sd.num_cells for sd in subdomains if sd.dim < self.nd - 1)
        )

        if len(self._fractures) == 0:
            # Domain without fractures. Put the source in the center of the domain.
            sd = subdomains[0]
            closest_cell = sd.closest_cell(
                np.array([x_mean, y_mean, 0]).reshape((3, 1))
            )
            src_ambient[closest_cell] = 1.0
        else:
            x, y, z = np.concatenate(
                [sd.cell_centers for sd in subdomains if sd.dim == self.nd - 1], axis=1
            )
            source_loc = np.argmin((x - x_mean) ** 2 + (y - y_mean) ** 2)
            src_fracture[source_loc] = 1

        return super().fluid_source(subdomains) + pp.ad.DenseArray(
            np.concatenate([src_ambient, src_fracture, src_intersection])
        )


class ModelProperties:
    def _is_nonlinear_problem(self) -> bool:
        """Check if the model is nonlinear."""
        return False


class StochasticModel(
    StochasticGeometry,
    FTHM_Solver.IterativeSolverMixin,
    Source,
    ModelProperties,
    pp.SinglePhaseFlow,
):
    pass


class BenchmarkModel(
    Source,
    FTHM_Solver.IterativeSolverMixin,
    ModelProperties,
    FlowBenchmark2dCase4Model,
):
    # We may want to look at this at some point, but for now, consider it untested and
    # optional.
    pass


if True:
    model_class = StochasticModel
else:
    model_class = BenchmarkModel


def reset_model_state(model):
    """Reset the model state to a clean state.

    This can be useful to run several simulations with the same model (discretization
    etc.) but, say, with different solver parameters.
    """
    mdg = model.mdg

    num_cells = sum(sd.num_cells for sd in mdg.subdomains())
    num_interface_cells = sum(intf.num_cells for intf in mdg.interfaces())

    zeros = np.zeros(num_cells + num_interface_cells, dtype=float)
    model.equation_system.set_variable_values(
        values=zeros, additive=False, time_step_index=0
    )
    model.equation_system.set_variable_values(
        values=zeros, additive=False, iterate_index=0
    )

    model.time_manager = pp.TimeManager(schedule=[0, 1], dt_init=1, constant_dt=True)

# %% [markdown]
# "mesh_arguments" are not forced atm

# %%
model_params = {
    "solid_constants": solid_constants_2d,
    "linear_solver": {"preconditioner_factory": FTHM_Solver.mass_balance_factory},
    # Control the number of fractures here.
    "num_fractures": 5,
    # This is the simplest way to control the cell size. You can also do
    # 'cell_size_fracture' and 'cell_size_boundary'.
   # "meshing_arguments": {"cell_size": 0.2,
                          #"cell_size_min": 0.05,         # avoid too-small elements
                          #"cell_size_fracture": 0.1,    # fine mesh around fractures
                          #"cell_size_fracture_min": 0.0045,    # fine mesh around fractures
                          #"cell_size_boundary": 0.2      # coarser mesh at outer boundary
    #                     },
    # Control the name of the gmsh file here.
    "meshing_kwargs": {"file_name": "mesh_2d"}
}

# %% [markdown]
# Model initialization

# %%
model = model_class(model_params)
model.prepare_simulation()


linear_solver_opts = {
    # This line PETSc print the residual norm at each iteration.
    #"ksp_monitor": None,
    #"ksp_view": None,
    "ksp_type": 'bcgs',#"preonly",#"tfqmr1",#"gmres1", #"richardson0", #"bicg0", #"bcgs1",  # Change the Krylov method
    "interface_darcy_flux": {"pc_type": "lu"}, # fix this to ilu for now
    "mass_balance": {"pc_type": "lu"},
}

model.params["linear_solver"].update({"options": linear_solver_opts})

# %%
# Compute actual lengths of the generated fractures
fractures = model.fractures
actual_lengths = [
    np.linalg.norm(frac.pts[:, 1] - frac.pts[:, 0])
    for frac in fractures
]

plt.hist(actual_lengths, bins=20, edgecolor='black')
plt.title("Distribution of Fracture Lengths")
plt.xlabel("Length")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# Recommend cell size near fractures
min_length = min(actual_lengths)

print(f"\n Smallest fracture: {min_length:.4f}")
# Out:
#  Smallest fracture: 0.2797

# %%
try:
    pp.run_time_dependent_model(model, {"prepare_simulation": False})
    pprint(f"Simulation completed successfully with {model._krylov_iters} iterations.")
except Exception as e:
        print(f"Solver failed!")
        print(f" Error: {e}")
# Out:
# 'Simulation completed successfully with [0, 4] iterations.'

# %%
#%%
pp.plot_grid(
    model.mdg,
    "pressure",
    figsize=(10, 8),
    linewidth=0.2,
    title='Pressure',
    plot_2d=True,
)

# %%
model.mdg.subdomains
# Out:
# <bound method MixedDimensionalGrid.subdomains of Mixed-dimensional grid containing 8 grids and 9 interfaces.
# Maximum dimension present: 2
# Minimum dimension present: 0
# 1 grids of dimension 2 with in total 466 cells
# 5 grids of dimension 1 with in total 39 cells
# 2 grids of dimension 0 with in total 2 cells
# 5 interfaces between grids of dimension 2 and 1 with in total 78 mortar cells.
# 4 interfaces between grids of dimension 1 and 0 with in total 8 mortar cells.
# >

# %%
reset_model_state(model)
    
linear_solver_opts = {
        "ksp_type": ksp,
        "interface_darcy_flux": {"pc_type": pc_interface},
        "mass_balance": {"pc_type": pc_mass}
}

# %%
model._krylov_iters=[0]
model._solve_time=[0]
model._construction_time=[0]

# %%
# Define solver types and preconditioners
ksp_types = ["gmres", "bcgs", "tfqmr"]
preconditioners_mass = ["ilu", "lu", "sor", "jacobi", "bjacobi", "asm",  "gamg"]
preconditioners_interface = ["jacobi", "bjacobi", "asm",  "gamg"]#["ilu", "lu", "sor"]

# Generate all combinations
solver_combinations = list(itertools.product(ksp_types, preconditioners_interface,preconditioners_mass))

# Store results
results = []

for idx, (ksp, pc_interface, pc_mass) in enumerate(solver_combinations):
    print(f"\n➡️ Running combination #{idx + 1}: {ksp} + {pc_mass} + {pc_interface}")
    
    reset_model_state(model)
    
    linear_solver_opts = {
        "ksp_type": ksp,
        "interface_darcy_flux": {"pc_type": pc_interface},
        "mass_balance": {"pc_type": pc_mass}
    }
   
    model.params["linear_solver"].update({"options": linear_solver_opts})
      
    try:
        model = model_class(model_params)
        model.prepare_simulation()
        start = time.time()
        pp.run_time_dependent_model(model, {"prepare_simulation": False})
        end = time.time()

        results.append({
            "Combination #": idx,
            "KSP Type": ksp,
            "PC Mass": pc_mass,
            "PC Interface": pc_interface,
            "Converged": True,
            "Krylov Iters": model._krylov_iters[-1],
            "Construction Time (s)": model._construction_time[-1],
            "Solve Time (s)": model._solve_time[-1],
            "Total Time (s)": model._construction_time[-1] + model._solve_time[-1],
            "Tic Toc Time (s)": end - start
            })
      
    except Exception as e:
        print(f"❌ Failed!")
        print(f"   ⚠️ Error: {type(e).__name__}: {e}")
        # print(f" Error: {e}")
        results.append({
            "Combination #": idx,
            "KSP Type": ksp,
            "PC Mass": pc_mass,
            "PC Interface": pc_interface,
            "Converged": False,
            "Krylov Iters": None,
            "Construction Time (s)": None,
            "Solve Time (s)": None,
            "Total Time (s)": None,
            "Tic Toc Time (s)": None
            })
    
# Convert results to DataFrame and save
df_results = pd.DataFrame(results)
# Out:
# ➡️ Running combination #1: gmres + ilu + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #2: gmres + lu + jacobi
#
#
# ➡️ Running combination #3: gmres + sor + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #4: gmres + jacobi + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #5: gmres + bjacobi + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #6: gmres + asm + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #7: gmres + gamg + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #8: gmres + ilu + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #9: gmres + lu + bjacobi
#
#
# ➡️ Running combination #10: gmres + sor + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #11: gmres + jacobi + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #12: gmres + bjacobi + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #13: gmres + asm + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #14: gmres + gamg + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #15: gmres + ilu + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #16: gmres + lu + asm
#
#
# ➡️ Running combination #17: gmres + sor + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #18: gmres + jacobi + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #19: gmres + bjacobi + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #20: gmres + asm + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #21: gmres + gamg + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #22: gmres + ilu + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #23: gmres + lu + gamg
#
#
# ➡️ Running combination #24: gmres + sor + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #25: gmres + jacobi + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #26: gmres + bjacobi + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #27: gmres + asm + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #28: gmres + gamg + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #29: bcgs + ilu + jacobi
#
#
# ➡️ Running combination #30: bcgs + lu + jacobi
#
#
# ➡️ Running combination #31: bcgs + sor + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #32: bcgs + jacobi + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -5. Check the solver options and the problem setup.
#
# ➡️ Running combination #33: bcgs + bjacobi + jacobi
#
#
# ➡️ Running combination #34: bcgs + asm + jacobi
#
#
# ➡️ Running combination #35: bcgs + gamg + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #36: bcgs + ilu + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #37: bcgs + lu + bjacobi
#
#
# ➡️ Running combination #38: bcgs + sor + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #39: bcgs + jacobi + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -5. Check the solver options and the problem setup.
#
# ➡️ Running combination #40: bcgs + bjacobi + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #41: bcgs + asm + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #42: bcgs + gamg + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #43: bcgs + ilu + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #44: bcgs + lu + asm
#
#
# ➡️ Running combination #45: bcgs + sor + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #46: bcgs + jacobi + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -5. Check the solver options and the problem setup.
#
# ➡️ Running combination #47: bcgs + bjacobi + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #48: bcgs + asm + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #49: bcgs + gamg + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #50: bcgs + ilu + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #51: bcgs + lu + gamg
#
#
# ➡️ Running combination #52: bcgs + sor + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #53: bcgs + jacobi + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #54: bcgs + bjacobi + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #55: bcgs + asm + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #56: bcgs + gamg + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #57: tfqmr + ilu + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #58: tfqmr + lu + jacobi
#
#
# ➡️ Running combination #59: tfqmr + sor + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #60: tfqmr + jacobi + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #61: tfqmr + bjacobi + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #62: tfqmr + asm + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #63: tfqmr + gamg + jacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #64: tfqmr + ilu + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #65: tfqmr + lu + bjacobi
#
#
# ➡️ Running combination #66: tfqmr + sor + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #67: tfqmr + jacobi + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #68: tfqmr + bjacobi + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #69: tfqmr + asm + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #70: tfqmr + gamg + bjacobi
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #71: tfqmr + ilu + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #72: tfqmr + lu + asm
#
#
# ➡️ Running combination #73: tfqmr + sor + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #74: tfqmr + jacobi + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #75: tfqmr + bjacobi + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #76: tfqmr + asm + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #77: tfqmr + gamg + asm
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #78: tfqmr + ilu + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #79: tfqmr + lu + gamg
#
#
# ➡️ Running combination #80: tfqmr + sor + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #81: tfqmr + jacobi + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #82: tfqmr + bjacobi + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #83: tfqmr + asm + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.
#
# ➡️ Running combination #84: tfqmr + gamg + gamg
#
# ❌ Failed!
#    ⚠️ Error: RuntimeError: Solver did not converge. Reason: -3. Check the solver options and the problem setup.

# %%
df_results
# Out:
#     Combination # KSP Type  PC Mass PC Interface  Converged  Krylov Iters  \
# 0               0    gmres      ilu       jacobi      False           NaN
# 1               1    gmres       lu       jacobi       True          12.0
# 2               2    gmres      sor       jacobi      False           NaN
# 3               3    gmres   jacobi       jacobi      False           NaN
# 4               4    gmres  bjacobi       jacobi      False           NaN
# ..            ...      ...      ...          ...        ...           ...
# 79             79    tfqmr      sor         gamg      False           NaN
# 80             80    tfqmr   jacobi         gamg      False           NaN
# 81             81    tfqmr  bjacobi         gamg      False           NaN
# 82             82    tfqmr      asm         gamg      False           NaN
# 83             83    tfqmr     gamg         gamg      False           NaN
#
#     Construction Time (s)  Solve Time (s)  Total Time (s)  Tic Toc Time (s)
# 0                     NaN             NaN             NaN               NaN
# 1                0.352375         0.05197        0.404345          3.071761
# 2                     NaN             NaN             NaN               NaN
# 3                     NaN             NaN             NaN               NaN
# 4                     NaN             NaN             NaN               NaN
# ..                    ...             ...             ...               ...
# 79                    NaN             NaN             NaN               NaN
# 80                    NaN             NaN             NaN               NaN
# 81                    NaN             NaN             NaN               NaN
# 82                    NaN             NaN             NaN               NaN
# 83                    NaN             NaN             NaN               NaN
#
# [84 rows x 10 columns]

# %%
df_results.head()
# Out:
#    Combination # KSP Type  PC Mass PC Interface  Converged  Krylov Iters  \
# 0              0    gmres      ilu       jacobi      False           NaN
# 1              1    gmres       lu       jacobi       True          12.0
# 2              2    gmres      sor       jacobi      False           NaN
# 3              3    gmres   jacobi       jacobi      False           NaN
# 4              4    gmres  bjacobi       jacobi      False           NaN
#
#    Construction Time (s)  Solve Time (s)  Total Time (s)  Tic Toc Time (s)
# 0                    NaN             NaN             NaN               NaN
# 1               0.352375         0.05197        0.404345          3.071761
# 2                    NaN             NaN             NaN               NaN
# 3                    NaN             NaN             NaN               NaN
# 4                    NaN             NaN             NaN               NaN

# %%
plt.figure(figsize=(12, 6))
plt.bar(df_results["Combination #"], df_results["Total Time (s)"], color="blue", edgecolor="k", alpha=0.5, label="Total Time")
plt.bar(df_results["Combination #"], df_results["Tic Toc Time (s)"], color="pink", edgecolor="k", alpha=0.5,  label="Tic Toc Time")
#plt.bar(df_results2["Combination #"], df_results2["Time (s)"], color="yellow", edgecolor="k", alpha=0.5)
plt.xlabel("Combination #")
plt.ylabel("seconds")
plt.title("Time per Solver Combination")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Filter to combinations where PC Interface == 'ilu' and Total Time is valid
df_flux_ilu = df_results[df_results["PC Interface"] == "ilu" ]
df_flux_lu = df_results[df_results["PC Interface"] == "lu"] 
df_flux_sor = df_results[df_results["PC Interface"] == "sor"] 

df_flux_ilu["label"] = df_flux_ilu["KSP Type"] + " + " + df_flux_ilu["PC Mass"]


# Plot Total Time for each combination
plt.figure(figsize=(10, 6))
plt.bar(df_flux_ilu["Combination #"], df_flux_ilu["Total Time (s)"], color="red", edgecolor="k",alpha=0.5, label='PC_flux = ilu' )
plt.bar(df_flux_ilu["Combination #"], df_flux_lu["Total Time (s)"], color="green", edgecolor="k", alpha=0.5, label='PC_flux = lu')
plt.bar(df_flux_ilu["Combination #"], df_flux_sor["Total Time (s)"], color="yellow", edgecolor="k", alpha=0.5, label='PC_flux = sor')
plt.xlabel("Combination #")
plt.ylabel("Time (s)")
plt.legend()
plt.title("Total Time for Each Solver Combination with PC Interface = ilu, lu, sor")
#plt.xticks(df_flux_ilu["Combination #"], rotation=90)
plt.xticks(ticks=df_flux_ilu["Combination #"], labels=df_flux_ilu["label"], rotation=90)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10256/2487395085.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flux_ilu["label"] = df_flux_ilu["KSP Type"] + " + " + df_flux_ilu["PC Mass"]

# %%
# Filter to combinations where PC Interface == 'ilu' and Total Time is valid


preconditioners_interface[0]
df_flux_0 = df_results[df_results["PC Interface"] == preconditioners_interface[0]]
df_flux_1 = df_results[df_results["PC Interface"] == preconditioners_interface[1]] 
df_flux_2 = df_results[df_results["PC Interface"] == preconditioners_interface[2]] 

df_flux_0["label"] = df_flux_0["KSP Type"] + " + " + df_flux_0["PC Mass"]


# Plot Total Time for each combination
plt.figure(figsize=(10, 6))
plt.bar(df_flux_0["Combination #"], df_flux_0["Total Time (s)"], color="red", edgecolor="k",alpha=0.5, label= preconditioners_interface[0] )
plt.bar(df_flux_0["Combination #"], df_flux_1["Total Time (s)"], color="green", edgecolor="k", alpha=0.5, label=preconditioners_interface[1])
plt.bar(df_flux_0["Combination #"], df_flux_2["Total Time (s)"], color="yellow", edgecolor="k", alpha=0.5, label=preconditioners_interface[2])
plt.xlabel("Combination #")
plt.ylabel("Time (s)")
plt.legend()
plt.title("Total Time for Each Solver Combination with PC Interface")
#plt.xticks(df_flux_ilu["Combination #"], rotation=90)
plt.xticks(ticks=df_flux_0["Combination #"], labels=df_flux_0["label"], rotation=90)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10256/1317228893.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flux_0["label"] = df_flux_0["KSP Type"] + " + " + df_flux_0["PC Mass"]

# %%
# Plot Total Time for each combination
plt.figure(figsize=(10, 6))
plt.bar(df_flux_ilu["Combination #"], df_flux_ilu["Tic Toc Time (s)"], color="red", edgecolor="k",alpha=0.5, label='PC_flux = ilu' )
plt.bar(df_flux_ilu["Combination #"], df_flux_lu["Tic Toc Time (s)"], color="green", edgecolor="k", alpha=0.5, label='PC_flux = lu')
plt.bar(df_flux_ilu["Combination #"], df_flux_sor["Tic Toc Time (s)"], color="yellow", edgecolor="k", alpha=0.5, label='PC_flux = sor')
plt.xlabel("Combination #")
plt.ylabel("Time (s)")
plt.legend()
plt.title("Tic Toc Time for Each Solver Combination with PC Interface = ilu, lu, sor")
#plt.xticks(df_flux_ilu["Combination #"], rotation=90)
plt.xticks(ticks=df_flux_ilu["Combination #"], labels=df_flux_ilu["label"], rotation=90)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %%
df_flux_ilu
# Out:
#     Combination # KSP Type  PC Mass PC Interface  Converged  Krylov Iters  \
# 0               0    gmres      ilu          ilu       True          54.0
# 1               1    gmres       lu          ilu       True           7.0
# 2               2    gmres      sor          ilu      False           NaN
# 3               3    gmres   jacobi          ilu      False           NaN
# 4               4    gmres  bjacobi          ilu       True          54.0
# 5               5    gmres      asm          ilu       True          54.0
# 6               6    gmres     gamg          ilu       True          34.0
# 21             21     bcgs      ilu          ilu       True          33.0
# 22             22     bcgs       lu          ilu       True           4.0
# 23             23     bcgs      sor          ilu       True          71.0
# 24             24     bcgs   jacobi          ilu      False           NaN
# 25             25     bcgs  bjacobi          ilu       True          33.0
# 26             26     bcgs      asm          ilu       True          33.0
# 27             27     bcgs     gamg          ilu       True          22.0
# 42             42    tfqmr      ilu          ilu       True          74.0
# 43             43    tfqmr       lu          ilu       True           8.0
# 44             44    tfqmr      sor          ilu       True         175.0
# 45             45    tfqmr   jacobi          ilu      False           NaN
# 46             46    tfqmr  bjacobi          ilu       True          74.0
# 47             47    tfqmr      asm          ilu       True          74.0
# 48             48    tfqmr     gamg          ilu       True          50.0
#
#     Construction Time (s)  Solve Time (s)  Total Time (s)  Tic Toc Time (s)  \
# 0                0.003422        0.006837        0.010259          0.216645
# 1                0.009371        0.001429        0.010799          0.239506
# 2                     NaN             NaN             NaN               NaN
# 3                     NaN             NaN             NaN               NaN
# 4                0.003035        0.007036        0.010071          0.170656
# 5                0.004110        0.008175        0.012285          0.206527
# 6                0.009224        0.009926        0.019150          0.206023
# 21               0.003821        0.004039        0.007860          0.201927
# 22               0.010257        0.001286        0.011543          0.196751
# 23               0.003275        0.009120        0.012394          0.198003
# 24                    NaN             NaN             NaN               NaN
# 25               0.003004        0.004527        0.007530          0.173764
# 26               0.003809        0.004773        0.008582          0.216655
# 27               0.009639        0.008645        0.018284          0.194966
# 42               0.003408        0.004498        0.007906          0.176666
# 43               0.009705        0.001579        0.011284          0.176254
# 44               0.003293        0.011687        0.014979          0.199326
# 45                    NaN             NaN             NaN               NaN
# 46               0.004727        0.006739        0.011466          0.194031
# 47               0.005058        0.006263        0.011321          0.208225
# 48               0.011580        0.010993        0.022572          0.215150
#
#               label
# 0       gmres + ilu
# 1        gmres + lu
# 2       gmres + sor
# 3    gmres + jacobi
# 4   gmres + bjacobi
# 5       gmres + asm
# 6      gmres + gamg
# 21       bcgs + ilu
# 22        bcgs + lu
# 23       bcgs + sor
# 24    bcgs + jacobi
# 25   bcgs + bjacobi
# 26       bcgs + asm
# 27      bcgs + gamg
# 42      tfqmr + ilu
# 43       tfqmr + lu
# 44      tfqmr + sor
# 45   tfqmr + jacobi
# 46  tfqmr + bjacobi
# 47      tfqmr + asm
# 48     tfqmr + gamg

# %%
plt.plot(model._solve_time)
#plt.plot(model._construction_time)
plt.xlabel("Time step")
plt.ylabel("Time (s)")
plt.title("Time per Time Step")
plt.legend(["Solve Time", "Construction Time"])
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %%
len(model._solve_time)
# Out:
# 148
